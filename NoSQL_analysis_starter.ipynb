# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pymongo import MongoClient
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20
query = {'scores.Hygiene': 20}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)
# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6596318a01c0cae9f26f256f'),
#  'geocode': {'latitude': Decimal128('50.769705'),
#              'longitude': Decimal128('0.27694')},
#  'latitude': None,
# ...

# %%
# Import Pandas
import pandas as pd

# %%
# Convert the result to a Pandas DataFrame
hygiene_20_df = pd.DataFrame(results)

# Display the number of rows in the DataFrame
hygiene_20_df.info()
# Display the first 10 rows of the DataFrame
hygiene_20_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41 entries, 0 to 40
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         41 non-null     object
#  1   FHRSID                      41 non-null     int64
#  2   ChangesByServerID           41 non-null     int64
#  3   LocalAuthorityBusinessID    41 non-null     object
#  4   BusinessName                41 non-null     object
#  5   BusinessType                41 non-null     object
#  6   BusinessTypeID              41 non-null     int64
#  7   AddressLine1                41 non-null     object
#  8   AddressLine2                41 non-null     object
#  9   AddressLine3                41 non-null     object
#  10  AddressLine4                41 non-null     object
#  11  PostCode                    41 non-null     object
#  12  Phone                       41 non-null     object
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# First import and use regex to search for phrase that contain 'London'
import re
p = re.compile(r'\bLondon\b', re.IGNORECASE)
query = {'LocalAuthorityName': {'$regex': p}}
result = list(establishments.find(query))
pprint(result)
# Out:
# [{'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#   'AddressLine2': 'Sheppy Kent',
#   'AddressLine3': '',
#   'AddressLine4': '',
#   'BusinessName': "Charlie's",
#   'BusinessType': 'Other catering premises',
#   'BusinessTypeID': 7841,
#   'ChangesByServerID': 0,
#   'Distance': 4627.439467780196,
#   'FHRSID': 621707,
#   'LocalAuthorityBusinessID': 'PI/000025307',
#   'LocalAuthorityCode': '508',
#   'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#   'LocalAuthorityName': 'City of London Corporation',
#   'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'ME12',
#   'RatingDate': '2021-10-18T00:00:00',
#   'RatingKey': 'fhrs_4_en-gb',
#   'RatingValue': 4,
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('6596318a01c0cae9f26f3f93'),
#   'geocode': {'latitude': Decimal128('51.369321'),
# ...

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
query = {'LocalAuthorityName': 'City of London Corporation', 'RatingValue': {'$gte': 4}}

# Use count_documents to display the number of documents in the result
establishments.count_documents(query)

# Display the first document in the results using pprint
results = establishments.find(query)
pprint(results[0])
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6596318a01c0cae9f26f3f93'),
#  'geocode': {'latitude': Decimal128('51.369321'),
#              'longitude': Decimal128('0.508551')},
# ...

# %%
# Convert the result to a Pandas DataFrame
London_RS4_df = pd.DataFrame(results)
# Display the number of rows in the DataFrame
London_RS4_df.info()
# Display the first 10 rows of the DataFrame
London_RS4_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   _id                         33 non-null     object
#  1   FHRSID                      33 non-null     int64
#  2   ChangesByServerID           33 non-null     int64
#  3   LocalAuthorityBusinessID    33 non-null     object
#  4   BusinessName                33 non-null     object
#  5   BusinessType                33 non-null     object
#  6   BusinessTypeID              33 non-null     int64
#  7   AddressLine1                33 non-null     object
#  8   AddressLine2                33 non-null     object
#  9   AddressLine3                33 non-null     object
#  10  AddressLine4                33 non-null     object
#  11  PostCode                    33 non-null     object
#  12  Phone                       33 non-null     object
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
#find Penang Flavour's longitude and latitude
query = {"BusinessName":"Penang Flavours"}
fields = {'geocode.latitude': 1, 'geocode.longitude': 1}

results = establishments.find(query, fields)

for result in results:
    pprint(result)
# Out:
# {'_id': ObjectId('6596331a1f657e4fae009e9c'),
#  'geocode': {'latitude': None, 'longitude': None}}
# {'_id': ObjectId('659640069d8d1e9c56dc7103'),
#  'geocode': {'latitude': None, 'longitude': None}}
# {'_id': ObjectId('659642619d8d1e9c56dc7104'),
#  'geocode': {'latitude': '51.49014200', 'longitude': '0.08384000'}}

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000

query = {
    '$and': [
        {'geocode.latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search}},
        {'geocode.longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search}}
    ]
}

sort = [('score.Hygiene', 1)] 

# Print the results

results = db.establishments.find(query).sort(sort).limit(5)

#total_count = db.establishments.count_documents(query)

for result in results:
    pprint(result)
# Out:
# {'AddressLine1': '49 Lakedale Road',
#  'AddressLine2': '',
#  'AddressLine3': 'Plumstead',
#  'AddressLine4': 'Greenwich',
#  'BusinessName': 'Kingsmeat Smokehouse',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4646.958610147575,
#  'FHRSID': 1489059,
#  'LocalAuthorityBusinessID': '15077',
#  'LocalAuthorityCode': '511',
#  'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#  'LocalAuthorityName': 'Greenwich',
#  'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'SE18 1PR',
#  'RatingDate': '1901-01-01T00:00:00',
#  'RatingKey': 'fhrs_awaitinginspection_en-gb',
#  'RatingValue': None,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('6596318b01c0cae9f26f7dc5'),
#  'geocode': {'latitude': Decimal128('51.4863774'),
#              'longitude': Decimal128('0.0913011')},
#  'latitude': None,
# ...

# %%
# Convert result to Pandas DataFrame
Near_PF_Df = pd.DataFrame(results)

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

match_query = {'$match': {"score.Hygiene": 0}}
group_query =  {'$group': {'_id': '$LocalAuthorityName','count': { '$sum': 1 }}}
sort_values = {'$sort': { 'count': 1}}
pipeline = [match_query, group_query, sort_values]

result = list(establishments.aggregate(pipeline))

# Print the number of documents in the result
print(len(result))

# Print the first 10 results
pprint(result{10})
# Out:
# Number of Documents After Match Stage: 0

# %%
# Convert the result to a Pandas DataFrame
pipeline_df = pd.DataFrame(result)

# Display the number of rows in the DataFrame
pipeline_df.info()
# Display the first 10 rows of the DataFrame
pipeline_df.head(10)
